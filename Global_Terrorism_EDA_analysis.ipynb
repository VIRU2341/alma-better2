# %% [markdown]
# <a href="https://colab.research.google.com/github/VIRU2341/alma-better2/blob/main/Global_Terrorism_EDA_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Project Name**    - Global Terrorism  Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Project By**      - Virendra Singh Rawat

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# This EDA project is on Global Terrorism analysis.The Global Terrorism Database (GTD) is an open-source database including information on terrorist attacks around the world from 1970 through 2017. The GTD includes systematic data on domestic as well as international terrorist incidents that have occurred during this time period and now includes more than 180,000 attacks. The database is maintained by researchers at the National Consortium for the Study of Terrorism and Responses to Terrorism (START), headquartered at the University of Maryland. Exploring and analyzing the data to discover key findings pertaining to terrorist activities.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/VIRU2341/alma-better2.git

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# **Lets explore and analyze the dataset and find some insights.**
#
# 1.Which country/city/region has the most number of terror attacks?
#
# 2.How many peoples are killed and wounded in different country/city/region?.
#
# 3.How many peoples are killed and wounded in different year?.
#
# 4.Which year has the maximum number of terror attacks?
#
# 4.what are the types of target?
#
# 5.What are the different methods of attacks?

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# My task is to explore and analyse the data to discover the important patterns and strategy of terrorist how they attack,which country,state,city,region they attack.What are the casualities done by them,which will help to counter their attacks.Different types of policy and strategy can be made to defeat the terrorist by exploring and visualizing the data.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import matplotlib.pyplot as plt
# %matplotlib inline
import plotly.express as px

# %% [markdown]
# ### Dataset Loading

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/Global Terrorism Data.csv', encoding='latin1')
# Out:
# <ipython-input-5-d9a1f6be7441>:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/drive/MyDrive/Global Terrorism Data.csv', encoding='latin1')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.shape
# Out:
# (181691, 135)

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
for i in df.columns:
    print(i,end=", ")
# Out:
# eventid, iyear, imonth, iday, approxdate, extended, resolution, country, country_txt, region, region_txt, provstate, city, latitude, longitude, specificity, vicinity, location, summary, crit1, crit2, crit3, doubtterr, alternative, alternative_txt, multiple, success, suicide, attacktype1, attacktype1_txt, attacktype2, attacktype2_txt, attacktype3, attacktype3_txt, targtype1, targtype1_txt, targsubtype1, targsubtype1_txt, corp1, target1, natlty1, natlty1_txt, targtype2, targtype2_txt, targsubtype2, targsubtype2_txt, corp2, target2, natlty2, natlty2_txt, targtype3, targtype3_txt, targsubtype3, targsubtype3_txt, corp3, target3, natlty3, natlty3_txt, gname, gsubname, gname2, gsubname2, gname3, gsubname3, motive, guncertain1, guncertain2, guncertain3, individual, nperps, nperpcap, claimed, claimmode, claimmode_txt, claim2, claimmode2, claimmode2_txt, claim3, claimmode3, claimmode3_txt, compclaim, weaptype1, weaptype1_txt, weapsubtype1, weapsubtype1_txt, weaptype2, weaptype2_txt, weapsubtyp
# ...

# %%
df=df[["iyear","imonth","iday","country_txt","region_txt","provstate","city",
       "latitude","longitude","location","summary","attacktype1_txt","targtype1_txt",
       "gname","motive","weaptype1_txt","nkill","nwound","addnotes"]]
df.head()
# Out:
#    iyear  imonth  iday         country_txt                   region_txt  \
# 0   1970       7     2  Dominican Republic  Central America & Caribbean
# 1   1970       0     0              Mexico                North America
# 2   1970       1     0         Philippines               Southeast Asia
# 3   1970       1     0              Greece               Western Europe
# 4   1970       1     0               Japan                    East Asia
#
#   provstate           city   latitude   longitude location summary  \
# 0       NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1   Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2    Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3    Attica         Athens  37.997490   23.762728      NaN     NaN
# 4   Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                   attacktype1_txt                targtype1_txt  \
# ...

# %%
df.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country",
                   "region_txt":"Region","provstate":"Province/State","city":"City",
                   "latitude":"Latitude","longitude":"Longitude","location":"Location",
                   "summary":"Summary","attacktype1_txt":"Attack Type","targtype1_txt":"Target Type",
                   "gname":"Group Name","motive":"Motive","weaptype1_txt":"Weapon Type",
                   "nkill":"Killed","nwound":"Wounded","addnotes":"Add Notes"},inplace=True)
# Out:
# <ipython-input-12-a989c62acfc6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={"iyear":"Year","imonth":"Month","iday":"Day","country_txt":"Country",

# %%
df.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#   Province/State           City   Latitude   Longitude Location Summary  \
# 0            NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1        Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2         Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3         Attica         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                       Attack Type                  Target Type  \
# ...

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            181691 non-null  int64
#  1   Month           181691 non-null  int64
#  2   Day             181691 non-null  int64
#  3   Country         181691 non-null  object
#  4   Region          181691 non-null  object
#  5   Province/State  181270 non-null  object
#  6   City            181257 non-null  object
#  7   Latitude        177135 non-null  float64
#  8   Longitude       177134 non-null  float64
#  9   Location        55495 non-null   object
#  10  Summary         115562 non-null  object
#  11  Attack Type     181691 non-null  object
#  12  Target Type     181691 non-null  object
#  13  Group Name      181691 non-null  object
#  14  Motive          50561 non-null   object
#  15  Weapon Type     181691 non-null  object
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# 11317

# %%
#dropping the duplicate values
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (170374, 19)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().sum()
# Out:
# Year                   0
# Month                  0
# Day                    0
# Country                0
# Region                 0
# Province/State       421
# City                 434
# Latitude            3978
# Longitude           3979
# Location          115420
# Summary            57219
# Attack Type            0
# Target Type            0
# Group Name             0
# Motive            120426
# Weapon Type            0
# Killed              9172
# Wounded            14985
# Add Notes         142674
# dtype: int64

# %%
df["Killed"]=df["Killed"].fillna(0)
df["Wounded"]=df["Wounded"].fillna(0)

# %%
df.shape
# Out:
# (170374, 19)

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ##From the above data we can see that there are 170374 rows and 19 columns with missing/null values:killed and wounded which i have replaced by 0.##

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# iyear:Year of the terror attack
#
#
# imonth:Month of the terror attack
#
#
# day:Day of the terror attack
#
#
# country_txt:Country where the terror attack happened
#
#
# region_txt:Region where the terror attacked happened
#
#
# provstate:Province/State is the state  where the terror attacked happened
#
#
# city:City of the terror attack
#
#
# location:Location of the terror attack
#
#
# weaptype1_txt":which Weapon Type is used in terror attack
#
#
# nkill:How many peoples Killed in terror attack.
#
#
# nwound":How many people are Wounded in terror attack.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
pd.Series({col:df[col].unique() for col in df})
# Out:
# Year              [1970, 1971, 1972, 1973, 1974, 1975, 1976, 197...
# Month                    [7, 0, 1, 2, 3, 4, 5, 6, 8, 9, 10, 11, 12]
# Day               [2, 0, 1, 3, 6, 8, 9, 10, 11, 12, 13, 14, 15, ...
# Country           [Dominican Republic, Mexico, Philippines, Gree...
# Region            [Central America & Caribbean, North America, S...
# Province/State    [nan, Federal, Tarlac, Attica, Fukouka, Illino...
# City              [Santo Domingo, Mexico city, Unknown, Athens, ...
# Latitude          [18.456792, 19.371887, 15.478598, 37.99749, 33...
# Longitude         [-69.951164, -99.086624, 120.599741, 23.762728...
# Location          [nan, Edes Substation, Caparra Shopping Center...
# Summary           [nan, 1/1/1970: Unknown African American assai...
# Attack Type       [Assassination, Hostage Taking (Kidnapping), B...
# Target Type       [Private Citizens & Property, Government (Dipl...
# Group Name        [MANO-D, 23rd of September Communist League, U...
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.
df.head()
# Out:
#    Year  Month  Day             Country                       Region  \
# 0  1970      7    2  Dominican Republic  Central America & Caribbean
# 1  1970      0    0              Mexico                North America
# 2  1970      1    0         Philippines               Southeast Asia
# 3  1970      1    0              Greece               Western Europe
# 4  1970      1    0               Japan                    East Asia
#
#   Province/State           City   Latitude   Longitude Location Summary  \
# 0            NaN  Santo Domingo  18.456792  -69.951164      NaN     NaN
# 1        Federal    Mexico city  19.371887  -99.086624      NaN     NaN
# 2         Tarlac        Unknown  15.478598  120.599741      NaN     NaN
# 3         Attica         Athens  37.997490   23.762728      NaN     NaN
# 4        Fukouka        Fukouka  33.580412  130.396361      NaN     NaN
#
#                       Attack Type                  Target Type  \
# ...

# %%
df.tail()
# Out:
#         Year  Month  Day      Country                      Region  \
# 181686  2017     12   31      Somalia          Sub-Saharan Africa
# 181687  2017     12   31        Syria  Middle East & North Africa
# 181688  2017     12   31  Philippines              Southeast Asia
# 181689  2017     12   31        India                  South Asia
# 181690  2017     12   31  Philippines              Southeast Asia
#
#          Province/State           City   Latitude   Longitude  \
# 181686  Middle Shebelle  Ceelka Geelow   2.359673   45.385034
# 181687         Lattakia         Jableh  35.407278   35.942679
# 181688      Maguindanao       Kubentog   6.900742  124.437908
# 181689          Manipur         Imphal  24.798346   93.940430
# 181690      Maguindanao  Cotabato City   7.209594  124.241966
#
#                                                  Location  \
# 181686     The incident occurred near the town of Balcad.
# 181687     The incident occurred at the Humaymim Airport.
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Country', 'Region', 'Province/State', 'City',
#        'Latitude', 'Longitude', 'Location', 'Summary', 'Attack Type',
#        'Target Type', 'Group Name', 'Motive', 'Weapon Type', 'Killed',
#        'Wounded', 'Add Notes'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Year                   0
# Month                  0
# Day                    0
# Country                0
# Region                 0
# Province/State       421
# City                 434
# Latitude            3978
# Longitude           3979
# Location          115420
# Summary            57219
# Attack Type            0
# Target Type            0
# Group Name             0
# Motive            120426
# Weapon Type            0
# Killed                 0
# Wounded                0
# Add Notes         142674
# dtype: int64

# %%
df.shape
# Out:
# (170374, 19)

# %%
pd.Series({col:df[col].unique() for col in df})
# Out:
# Year              [1970, 1971, 1972, 1973, 1974, 1975, 1976, 197...
# Month                    [7, 0, 1, 2, 3, 4, 5, 6, 8, 9, 10, 11, 12]
# Day               [2, 0, 1, 3, 6, 8, 9, 10, 11, 12, 13, 14, 15, ...
# Country           [Dominican Republic, Mexico, Philippines, Gree...
# Region            [Central America & Caribbean, North America, S...
# Province/State    [nan, Federal, Tarlac, Attica, Fukouka, Illino...
# City              [Santo Domingo, Mexico city, Unknown, Athens, ...
# Latitude          [18.456792, 19.371887, 15.478598, 37.99749, 33...
# Longitude         [-69.951164, -99.086624, 120.599741, 23.762728...
# Location          [nan, Edes Substation, Caparra Shopping Center...
# Summary           [nan, 1/1/1970: Unknown African American assai...
# Attack Type       [Assassination, Hostage Taking (Kidnapping), B...
# Target Type       [Private Citizens & Property, Government (Dipl...
# Group Name        [MANO-D, 23rd of September Communist League, U...
# ...

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# As  there are 135 columns which after doing manipilations in the data i have reduced to 19, i have filled missing values/null values with  0 in killed and wounded columns.
#
# After doing all the manipulation in the dataset these were the insights i found:
#
# 1.The maximum number of people killed in an event were: 1570.
#
# 2.The maximum number of people wounded in an event were: 8191.
#
# 3.The data consists of terrorist activities ranging from the year: 1970 to 2017.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
attacks=df["Year"].value_counts(dropna=False).sort_index().to_frame().reset_index().rename(columns={"index":"Year","Year":"Attacks"}).set_index("Year")
attacks.head()
# Chart - 1 visualization code
attacks.plot(kind="bar",figsize=(15,6),fontsize=13)
plt.title("year wise Attacks",fontsize=15)
plt.xlabel("Years",fontsize=15)
plt.ylabel("Number of Attacks",fontsize=15)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used this chart to compare the number of attacks yearly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart it can be seen clearly that  most number of attacks(16903) in 2014 whereas least number of attacks(471) in 1971.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The chart above shows that from year 1970 to 1978 the number of attacks are less than 2000,from year 1979 to 2011 the number of attacks are less than 6000 but from 2012 to 2017 the number of attacks have increased in which highest year is 2014 with 16903 terror attacks.

# %%
killing=df[["Year","Killed"]].groupby("Year").sum()
killing.head()
# Out:
#       Killed
# Year
# 1970   173.0
# 1971   172.0
# 1972   553.0
# 1973   367.0
# 1974   537.0

# %% [markdown]
# #### Chart - 2

# %%
# Chart -2 visualization code
killing.plot(kind="bar",figsize=(10,6))
plt.title("People Killed in each Year")
plt.xlabel("Years")
plt.ylabel("Number of People Killed")
# Out:
# Text(0, 0.5, 'Number of People Killed')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
#  I used the bar chart to compare yearly that how many peoples were killerd in terror attack yearly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart we can see that  the maximun number of people were killed in 2014,whereas the least number of people were killed in 1970

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
#  From the above chart it is clear that number of people killed from year 2012 to 2017 has suddenly increased,more the number of attacks more the peoples are killed in that attack.

# %%
wounded=df[["Year","Wounded"]].groupby("Year").sum()
wounded.head()
# Out:
#       Wounded
# Year
# 1970    212.0
# 1971     82.0
# 1972    409.0
# 1973    495.0
# 1974    864.0

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
wounded.plot(kind="bar",figsize=(10,6))
plt.title("People wounded in each Year")
plt.xlabel("Years")
plt.ylabel("Number of People wounded")
# Out:
# Text(0, 0.5, 'Number of People wounded')

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I used the bar chart to compare yearly that how many peoples were wounded in terror attack yearly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above chart we can see that the maximun number of people were wounded in 2015,whereas the least number of people were killed in 1971.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above chart it is clear that number of people wounded from year 2012 to 2017 has suddenly increased,more the number of attacks more the peoples are wounded in that attack.

# %%
city=df["City"].value_counts()[1:12]
city
# Out:
# Baghdad         7575
# Karachi         2164
# Mosul           2135
# Belfast         1945
# Mogadishu       1570
# Lima            1527
# Santiago        1210
# San Salvador    1131
# Kirkuk           921
# Beirut           890
# Athens           875
# Name: City, dtype: int64

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code

city.plot(kind="bar",figsize=(10,6))
plt.title("City wise Attacks",fontsize=13)
plt.xlabel("Cities",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# For counting and comparing the number of terror attacks in different cities.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above insight show that the city Baghdad has highest number of terror attack(7575).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The maximum terror attacks are in Baghdad which are approx 7575.The security of this city can be increased as it is the most terror city more than thrice the terror attcaks are happening as compared to other city.

# %%
killing=df[["City","Killed"]].groupby("City").sum().sort_values(by="Killed",ascending=False).drop("Unknown")
killing.head(10)
# Out:
#                 Killed
# City
# Baghdad        21118.0
# Mosul           7123.0
# Mogadishu       3908.0
# Karachi         3390.0
# New York City   2838.0
# Tikrit          2672.0
# Kabul           2493.0
# Ramadi          2307.0
# Maiduguri       2234.0
# Aleppo          2123.0

# %%
wounded=df[["City","Wounded"]].groupby("City").sum().sort_values(by="Wounded",ascending=False).drop("Unknown")
wounded.head(10)
# Out:
#                Wounded
# City
# Baghdad        56639.0
# New York City  16779.0
# Kabul           5973.0
# Mosul           5759.0
# Tokyo           5542.0
# Karachi         5503.0
# Beirut          5335.0
# Nairobi         5024.0
# Kirkuk          4978.0
# Mogadishu       4950.0

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
killing[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each City")
ax0.set_xlabel("Cities")
ax0.set_ylabel("Number of People Killed")

#Wounded
wounded[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each City")
ax1.set_xlabel("Cities")
ax1.set_ylabel("Number of People Wounded")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# For comparing and counting the number of people killed and wounded in different cities i use this bar plot.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From above insight shows that the city Baghdad has the maximum number of people killed(21118) and wounded(56639).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The most number of terror attacks are in Baghdad so obivously most people are killed and wounded in the terror attack.The terrorists are targeting Baghdad city.Security and the army should be increase in the city Barghdad.

# %%
group=df["Group Name"].value_counts()[1:10]
group
# Out:
# Taliban                                             7304
# Islamic State of Iraq and the Levant (ISIL)         5195
# Shining Path (SL)                                   3551
# Al-Shabaab                                          3266
# New People's Army (NPA)                             2693
# Farabundo Marti National Liberation Front (FMLN)    2441
# Boko Haram                                          2383
# Irish Republican Army (IRA)                         2362
# Revolutionary Armed Forces of Colombia (FARC)       2358
# Name: Group Name, dtype: int64

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
group.plot(kind="bar",color='red',figsize=(10,6))
plt.title("Group wise Attacks",fontsize=13)
plt.xlabel("Terrorist Groups",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# For comparing the attacks by different terror group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# So according to the above plot the highest number of terror attack are done by terrorist group Taliban(7304).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The maximum number of terror attacks are done by Taliban 7304,Islamic State of Iraq and the Levant (ISIL) 5195,Shining Path (SL) 3551,Al-Shabaab 3266,New People's Army (NPA) 2693,Farabundo M 2383,Irish Republican Army (IRA) 2362,
# Revolutionary Armed Forces of Colombia (FARC) 2358.Forces should focus on these terror group.

# %% [markdown]
# #### Chart - 7

# %%
wounded=df[["Group Name","Wounded"]].groupby("Group Name").sum().sort_values(by="Wounded",ascending=False).drop("Unknown")
wounded.head(10)
# Out:
#                                              Wounded
# Group Name
# Islamic State of Iraq and the Levant (ISIL)  30515.0
# Taliban                                      27794.0
# Al-Qaida                                     24512.0
# Liberation Tigers of Tamil Eelam (LTTE)      10919.0
# Al-Qaida in Iraq                             10286.0
# Tehrik-i-Taliban Pakistan (TTP)               9528.0
# Boko Haram                                    9370.0
# Al-Shabaab                                    7619.0
# Aum Shinri Kyo                                6003.0
# Kurdistan Workers' Party (PKK)                4904.0

# %%
killed=df[["Group Name","Killed"]].groupby("Group Name").sum().sort_values(by="Killed",ascending=False).drop("Unknown")
killed.head(10)
# Out:
#                                                    Killed
# Group Name
# Islamic State of Iraq and the Levant (ISIL)       38731.0
# Taliban                                           29182.0
# Boko Haram                                        20189.0
# Shining Path (SL)                                 11365.0
# Liberation Tigers of Tamil Eelam (LTTE)           10831.0
# Al-Shabaab                                         9292.0
# Farabundo Marti National Liberation Front (FMLN)   7976.0
# Nicaraguan Democratic Force (FDN)                  6657.0
# Tehrik-i-Taliban Pakistan (TTP)                    6030.0
# Revolutionary Armed Forces of Colombia (FARC)      5602.0

# %%
# Chart - 7 visualization code
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
killed[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed by each Group")
ax0.set_xlabel("Terrorist Groups")
ax0.set_ylabel("Number of people Killed")

#Wounded
wounded[:10].plot(kind="bar",color="cornflowerblue",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded by each Group")
ax1.set_xlabel("Terrorist Groups")
ax1.set_ylabel("Number of people Wounded")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# i used this chart to compare and count that how many peoples are killed and wounded by different group.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the above bar chart the most number of people are killed and wounded by ISIL group.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# ISIL,Tailiban ana AL-Qaida these three group killed and wounded the most number of people.

# %% [markdown]
# #### Chart - 8

# %%
attack=df["Attack Type"].value_counts()
attack
# Out:
# Bombing/Explosion                      80922
# Armed Assault                          41263
# Assassination                          18681
# Hostage Taking (Kidnapping)            10939
# Facility/Infrastructure Attack          9170
# Unknown                                 6896
# Unarmed Assault                          933
# Hostage Taking (Barricade Incident)      917
# Hijacking                                653
# Name: Attack Type, dtype: int64

# %%
# Chart - 8 visualization code
attack.plot(kind="bar",color='red',figsize=(12,6))
plt.title("Types of Attacks",fontsize=13)
plt.xlabel("Attack Types",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have used this graph to figure out what types of attacks the terrorists are doing.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight from the above chart can be clearly seen that bombing explosion (80922) and armed assault (41263) are the most types of attacks.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# More than 65% attacks are done by bombing and armed assault.Security forces should make some strategy to tackle the terrorists.

# %% [markdown]
# #### Chart - 9

# %%
killed=df[["Attack Type","Killed"]].groupby("Attack Type").sum().sort_values(by="Killed",ascending=False)
killed
# Out:
#                                        Killed
# Attack Type
# Armed Assault                        158766.0
# Bombing/Explosion                    156417.0
# Unknown                               31962.0
# Assassination                         24269.0
# Hostage Taking (Kidnapping)           23976.0
# Hostage Taking (Barricade Incident)    4478.0
# Hijacking                              3718.0
# Facility/Infrastructure Attack         3591.0
# Unarmed Assault                         880.0

# %%
wounded=df[["Attack Type","Wounded"]].groupby("Attack Type").sum().sort_values(by="Wounded",ascending=False)
wounded
# Out:
#                                       Wounded
# Attack Type
# Bombing/Explosion                    370247.0
# Armed Assault                         76912.0
# Hijacking                             17001.0
# Unknown                               14448.0
# Unarmed Assault                       14024.0
# Assassination                         13794.0
# Hostage Taking (Kidnapping)            6366.0
# Hostage Taking (Barricade Incident)    3961.0
# Facility/Infrastructure Attack         3740.0

# %%
# Chart - 9 visualization code
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
killed.plot(kind="bar",color="red",figsize=(15,6),ax=ax0)
ax0.set_title("People Killed in each Attack Type")
ax0.set_xlabel("Attack Types")
ax0.set_ylabel("Number of people Killed")

#Wounded
wounded.plot(kind="bar",color="red",figsize=(15,6),ax=ax1)
ax1.set_title("People Wounded in each Attack Type")
ax1.set_xlabel("Attack Types")
ax1.set_ylabel("Number of people Wounded")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have used this graph to figure out how many peoples are killed and wounded by different types of attacks done by terrorists.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight from the above chart can be clearly seen that most of the people are kileed in armed assault and bombing explosion.whereas most people are injured in bombing explosion.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Around 370247 are wounded in bombing explosion whereas 315183 peoples arekilled in armed assault and bombing explosion attacks.

# %% [markdown]
# #### Chart - 10

# %%
target=df["Target Type"].value_counts()
target
# Out:
# Private Citizens & Property       41290
# Military                          27488
# Police                            23743
# Government (General)              20208
# Business                          18160
# Transportation                     6041
# Unknown                            5229
# Religious Figures/Institutions     4279
# Educational Institution            4162
# Utilities                          4048
# Government (Diplomatic)            3452
# Terrorists/Non-State Militia       3002
# Journalists & Media                2840
# Violent Political Party            1803
# Airports & Aircraft                1308
# NGO                                 952
# Telecommunication                   914
# Tourists                            429
# Maritime                            341
# Food or Water Supply                295
# Abortion Related                    256
# Other                               134
# Name: Target Type, dtype: int64

# %%
# Chart - 10 visualization code
target.plot(kind="bar",color="red",figsize=(10,6))
plt.title("Types of Targets",fontsize=13)
plt.xlabel("Target Types",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To count and compare the  number of attacks on different target types i use this bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This insights shows that around 41290 attacks were on private citizens and property.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above chart it is clear that the terrorist target on these four target types, Private Citizens & Property(41290),Military   ( 27488),Police(23743),Government(General)20208,Business (18160).

# %% [markdown]
# #### Chart - 11

# %%
wounded=df[["Target Type","Wounded"]].groupby("Target Type").sum().sort_values(by="Wounded",ascending=False)
wounded
# Out:
#                                  Wounded
# Target Type
# Private Citizens & Property     177669.0
# Military                         70817.0
# Police                           64333.0
# Business                         54039.0
# Government (General)             40972.0
# Transportation                   40265.0
# Religious Figures/Institutions   24326.0
# Government (Diplomatic)          10341.0
# Educational Institution          10156.0
# Terrorists/Non-State Militia      8189.0
# Violent Political Party           5273.0
# Airports & Aircraft               3470.0
# Unknown                           3218.0
# Journalists & Media               1794.0
# Utilities                         1351.0
# Tourists                          1290.0
# Maritime                           907.0
# NGO                                889.0
# Telecommunication                  495.0
# Other                              419.0
# Food or Water Supply               234.0
# ...

# %%
killed=df[["Target Type","Killed"]].groupby("Target Type").sum().sort_values(by="Killed",ascending=False)
killed
# Out:
#                                   Killed
# Target Type
# Private Citizens & Property     138956.0
# Military                        105299.0
# Police                           53120.0
# Government (General)             25940.0
# Business                         23391.0
# Transportation                   13821.0
# Religious Figures/Institutions   13318.0
# Terrorists/Non-State Militia      9027.0
# Unknown                           4004.0
# Airports & Aircraft               3767.0
# Educational Institution           3713.0
# Violent Political Party           3553.0
# Government (Diplomatic)           3035.0
# Utilities                         1858.0
# Journalists & Media               1494.0
# Maritime                          1190.0
# NGO                               1057.0
# Tourists                           757.0
# Food or Water Supply               313.0
# Other                              252.0
# Telecommunication                  182.0
# ...

# %%
# Chart - 11 visualization code
fig=plt.figure()
ax0=fig.add_subplot(1,2,1)
ax1=fig.add_subplot(1,2,2)

#Killed
killed.plot(kind="bar",color='red',figsize=(17,6),ax=ax0)
ax0.set_title("People Killed in each Target Attack")
ax0.set_xlabel("Target Types")
ax0.set_ylabel("Number of people Killed")

#Wounded
wounded.plot(kind="bar",color='red',figsize=(17,6),ax=ax1)
ax1.set_title("People Wounded in each Target Attack")
ax1.set_xlabel("Target Types")
ax1.set_ylabel("Number of people Wounded")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To count and compare the number of people killed and wounded on different target types i use this bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This insights shows that around 138956 people were killed on attacks in private citizens and 105299 were killed im military  and around 177669 people were injured in  in private citizens.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above chart it is clear that the major casuality are on Private Citizens & Property,Military	,Police	,Business	and Government (General).

# %% [markdown]
# #### Chart - 12

# %%
grpcountry=df[["Group Name","Country"]].value_counts().drop("Unknown")
grpcountry.head(10)
# Out:
# <ipython-input-43-d0751b0b5d34>:1: PerformanceWarning: dropping on a non-lexsorted multi-index without a level parameter may impact performance.
#   grpcountry=df[["Group Name","Country"]].value_counts().drop("Unknown")
# Group Name                                        Country
# Taliban                                           Afghanistan       7249
# Islamic State of Iraq and the Levant (ISIL)       Iraq              4400
# Shining Path (SL)                                 Peru              3538
# Al-Shabaab                                        Somalia           2852
# New People's Army (NPA)                           Philippines       2691
# Farabundo Marti National Liberation Front (FMLN)  El Salvador       2420
# Revolutionary Armed Forces of Colombia (FARC)     Colombia          2341
# Irish Republican Army (IRA)                       United Kingdom    2272
# Kurdistan Workers' Party (PKK)                    Turkey            2061
# ...

# %%
# Chart - 12 visualization code
grpcountry.head(10).plot(kind="bar",color="cornflowerblue",figsize=(10,6))
plt.title("Countries with most attacks by a particular Group",fontsize=13)
plt.xlabel("(Terrorist Group,Country)",fontsize=13)
plt.xticks(fontsize=12)
plt.ylabel("Number of Attacks",fontsize=13)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To count and compare the number of attacks by different group on different country  i use this bar chart.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This insights shows that the most terror are in Afghanistan by the terrorist group Taliban.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# From the above chart it is clear that the major country suffering from terror are  Afghanistan(7249) by Taliban,Iraq  by Islamic State of Iraq and the Levant (ISIL)(4400) and Peru by Shining Path (SL) (3538).

# %% [markdown]
# #### Chart - 13

# %%
region=pd.crosstab(df.Year,df.Region)
region.head()
# Out:
# Region  Australasia & Oceania  Central America & Caribbean  Central Asia  \
# Year
# 1970                        1                            7             0
# 1971                        1                            5             0
# 1972                        5                            3             0
# 1973                        1                            6             0
# 1974                        1                           11             0
#
# Region  East Asia  Eastern Europe  Middle East & North Africa  North America  \
# Year
# 1970            2              12                          27            460
# 1971            1               3                          55            235
# 1972            0               1                          48             72
# 1973            2               1                          19             63
# 1974            4               2                          38            105
#
# ...

# %%
# Chart - 13 visualization code
region.plot(kind="area", stacked=False, alpha=0.5,figsize=(20,10))
plt.title("Region wise attacks",fontsize=20)
plt.xlabel("Years",fontsize=20)
plt.ylabel("Number of Attacks",fontsize=20)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To compare the number of attacks done by terrorists in different region.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight is that Before 2001, the regions were much closer together in terms of activity, eventually all dropping to a minimum in 2000. After 2001, the Middle East and South Asia have dictated the rise in terrorism numbers, with a significant increase in Sub-Saharan Africa as well.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight lead The Middle East and North Africa Regions has most taregeted.After 2001, the Middle East and South Asia have dictated the rise in terrorism numbers, with a significant increase in Sub-Saharan Africa as well.

# %% [markdown]
# #### Chart - 14

# %%
# Chart - 14 visualization code
data_after = df[df['Year']>=2001]
fig,ax = plt.subplots(figsize=(15,10),nrows=2,ncols=1)
ax[0] = pd.crosstab(df.Year,df.Region).plot(ax=ax[0])
ax[0].set_title('Change in Regions per Year')
ax[0].legend(loc='center left',bbox_to_anchor = (1,0.5))
ax[0].vlines(x=2001,ymin=0,ymax=7000,colors='red',linestyles='--')
pd.crosstab(data_after.Year,data_after.Region).plot.bar(stacked=True,ax=ax[1])
ax[1].set_title('After Declaration of War on Terror (2001-2017)')
ax[1].legend(loc='center left',bbox_to_anchor = (1,0.5))
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I have used this chart to compare the number of attacks done by terrorists in different region.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight is that Before 2001, the regions were much closer together in terms of activity, eventually all dropping to a minimum in 2000. After 2001, the Middle East and South Asia have dictated the rise in terrorism numbers, with a significant increase in Sub-Saharan Africa as well.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insight lead The Middle East and North Africa Regions has most taregeted.After 2001, the Middle East and South Asia have dictated the rise in terrorism numbers, with a significant increase in Sub-Saharan Africa as well.

# %% [markdown]
# #### Chart - 15 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True,cmap='RdYlGn')
# Out:
# <ipython-input-30-0694197ee718>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True,cmap='RdYlGn')
# <Axes: >

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Correlation heatmaps was used to find potential relationships between variables and to understand the strength of these relationships.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight from the chart is that kiled is correlated to wounded which is obvious.There is no such strong coorelation.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# ##1. When compared to attacks from 1970 onwards, the last 6 years scored a maximum.Government and security forces should look what wrong things are going from 2012 to 2017.
#
# ##2.The Middle East and North Africa Regions has most targeted.A strong policy against terrorists in this region should be made.
#
# ##3.Iraq,Pakistan and Afghanistan are the hub of terror where the most terror attacks are happened.Iraq with topmost.As the terror group like Taliban,ISIL are originated and controlled from these country only.Strict policy can be made by sending the militarty and ending the leaders of these terrorist group and a eye should be there so that no such terror group can be formed again.
#
# ##4..Maximum number of attacks are from Bombing/Explosions.Governments and security forces should investigate how and from where the terror group are getting these explosive and weapons.A team of bomb diffusive should be made and should be deployed in terror prone areas.
#
# ##5.The terrorist target the private Citizens and property  and then the  Military, Police, Government and so on.It is easier for terrorist to kill people and destroy the property.So a very strict checking should be done in cities like Bargdad where the attack is most.At every mall,crowded places, metro,airplane,transporated areas the checking should be done properly with proper bomb diffused team should be deployed and the maximum control of army and police should be their in cities like Barghdad.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Insights derived from the above EDA we can conclude that:
#
# 1.Attacks has increased from 2012 to 2017 and number of people killed more in these years as attack happened.
#
# 2.Iraq has the most attacks.
#
# 3.The Middle East and North Africa Regions has most targeted.
#
# 4.Maximum number of attacks are from Bombing/Explosions.
#
# 5.There are maximum number of attacks in Private citizens and Property.
#
# 6.Taliban and ISIL has a most active organisation.
#
# 7.Private Citizens and Property were attacked most followed by Military, Police, Government and so on.
#
# 8.The State and City that was most affected was Baghdad.
#
# 9.In the last decade 2014 had most number of terror attacks.
#
# 10.The most common attack type was Bombing/Explosion.
#
# 11.Explosives have been consistently the most popular weapon of choice for terrorists.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
